# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')

# %%
new_df = df.drop('price', axis='columns')
new_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price = df.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %%
reg = linear_model.LinearRegression()
reg.fit(new_df,price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# /Users/boyko/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:445: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
# reg.predict = reg.coef * area + reg.intercept
135.78767123*3300 + 180616.43835616432
# Out:
# 628715.7534151643

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color="blue")

# %%
d = pd.read_csv(areas.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-732b69b7fb62> in <module>
# ----> 1 d = pd.read_csv(areas.csv)
#
# NameError: name 'areas' is not defined

# %%
data = {'area':[1000, 1500, 2300, 3540, 4120, 4560, 5490, 3460, 4750, 2300, 9000, 8600, 7100]}
d = pd.DataFrame(data)

# %%
d
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
p = reg.predict(d)

# %%
d['prices'] = p
d.to_csv('prediction.excel')

# %%
df = pd.read_csv("canada_per_capita_income.csv")
df.rename(columns={'per capita income (US$)':'cost'}, inplace=True)
df.head()
# Out:
#    year         cost
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
# %matplotlib inline
plt.xlabel('с')
plt.ylabel('year')
plt.scatter(df.cost,df.year, color="red",marker="+")

# %%
new_df = df.drop('cost',axis='columns')
new_df.head()
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972
# 3  1973
# 4  1974

# %%
cost = df.cost
cost.head()
# Out:
# 0    3399.299037
# 1    3768.297935
# 2    4251.175484
# 3    4804.463248
# 4    5576.514583
# Name: cost, dtype: float64

# %%
reg = linear_model.LinearRegression()
reg.fit(new_df, year)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([828.46507522])

# %% [raw]
# reg.intercept_

# %%
reg.predict([[2020]])
# Out:
# /Users/boyko/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:445: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
# %matplotlib inline
plt.xlabel('income')
plt.ylabel('year')
plt.scatter(df.cost,df.year, color="red",marker="+")
plt.plot(df.cost,reg.predict(df[['cost']]), color='blue')
# Out:
# /Users/boyko/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - cost
# Feature names seen at fit time, yet now missing:
# - year
#
#   warnings.warn(message, FutureWarning)

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color="blue")
