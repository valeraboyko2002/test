# %%
import pandas as pd 

df = pd.read_csv("csv/salaries.csv")
df
# Out:
#        company                  job     degree  salary_more_then_100k
# 0       google      sales executive  bachelors                      0
# 1       google      sales executive    masters                      0
# 2       google     business manager  bachelors                      1
# 3       google     business manager    masters                      1
# 4       google  computer programmer  bachelors                      0
# 5       google  computer programmer    masters                      1
# 6   abc pharma      sales executive    masters                      0
# 7   abc pharma  computer programmer  bachelors                      0
# 8   abc pharma     business manager  bachelors                      0
# 9   abc pharma     business manager    masters                      1
# 10    facebook      sales executive  bachelors                      1
# 11    facebook      sales executive    masters                      1
# ...

# %%
inputs = df.drop('salary_more_then_100k', axis='columns')
target = df.salary_more_then_100k

# %%
from sklearn.preprocessing import LabelEncoder

le_company = LabelEncoder()
le_job = LabelEncoder()
le_degree = LabelEncoder()

# %%
inputs['company_n'] = le_company.fit_transform(inputs['company'])
inputs['job_n'] = le_job.fit_transform(inputs['job'])
inputs['degree_n'] = le_degree.fit_transform(inputs['degree'])

# %%
inputs.drop(['company','job','degree'], axis='columns', inplace=True)
inputs
# Out:
#     company_n  job_n  degree_n
# 0           2      2         0
# 1           2      2         1
# 2           2      0         0
# 3           2      0         1
# 4           2      1         0
# 5           2      1         1
# 6           0      2         1
# 7           0      1         0
# 8           0      0         0
# 9           0      0         1
# 10          1      2         0
# 11          1      2         1
# 12          1      0         0
# 13          1      0         1
# 14          1      1         0
# 15          1      1         1

# %%
inputs
# Out:
#     company_n  job_n  degree_n
# 0           2      2         0
# 1           2      2         1
# 2           2      0         0
# 3           2      0         1
# 4           2      1         0
# 5           2      1         1
# 6           0      2         1
# 7           0      1         0
# 8           0      0         0
# 9           0      0         1
# 10          1      2         0
# 11          1      2         1
# 12          1      0         0
# 13          1      0         1
# 14          1      1         0
# 15          1      1         1

# %%
from sklearn import tree

model = tree.DecisionTreeClassifier()
model.fit(inputs,target)
model.predict([[1,0,0]])
# Out:
# /Users/boyko/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:445: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
# HOMEWORK
import pandas as pd
df = pd.read_csv("csv/titanic.csv")

df[(df.Pclass == 1) & (df.Age >= 50) & (df.Age <= 60) & (df.Survived == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 195          196         1       1
# 268          269         1       1
# 299          300         1       1
# 366          367         1       1
# 449          450         1       1
# 496          497         1       1
# 513          514         1       1
# 571          572         1       1
# 587          588         1       1
# 591          592         1       1
# 647          648         1       1
# 660          661         1       1
# 765          766         1       1
# 820          821         1       1
# 857          858         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 195                               Lurette, Miss. Elise  female  58.0      0
# 268      Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# ...

# %%
df.drop(['Name','Ticket', 'PassengerId','Cabin','Embarked','SibSp'],axis='columns',inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# Parch         0
# Fare          0
# dtype: int64

# %%
df.dropna(subset = ['Age'],inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le_sex = LabelEncoder()
df['Sex_l'] = le_sex.fit_transform(df["Sex"])
df.drop('Sex',axis='columns',inplace=True)

# %%
df
# Out:
#      Survived  Pclass   Age  Parch     Fare  Sex_l
# 0           0       3  22.0      0   7.2500      1
# 1           1       1  38.0      0  71.2833      0
# 2           1       3  26.0      0   7.9250      0
# 3           1       1  35.0      0  53.1000      0
# 4           0       3  35.0      0   8.0500      1
# ..        ...     ...   ...    ...      ...    ...
# 885         0       3  39.0      5  29.1250      0
# 886         0       2  27.0      0  13.0000      1
# 887         1       1  19.0      0  30.0000      0
# 889         1       1  26.0      0  30.0000      1
# 890         0       3  32.0      0   7.7500      1
#
# [714 rows x 6 columns]

# %%
target = df.Survived
input_n = df.drop('Survived',axis='columns')

# %%
from sklearn import tree

model = tree.DecisionTreeClassifier()
model.fit(input_n,target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(input_n,target)
# Out:
# 0.9845938375350141

# %%
import seaborn as sn 
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')

# %%
input_n.head()
# Out:
#    Pclass   Age  Parch     Fare  Sex_l
# 0       3  22.0      0   7.2500      1
# 1       1  38.0      0  71.2833      0
# 2       3  26.0      0   7.9250      0
# 3       1  35.0      0  53.1000      0
# 4       3  35.0      0   8.0500      1

# %%
model.predict([[3,20,0,10,0]])
# Out:
# /Users/boyko/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:445: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])
