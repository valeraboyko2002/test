# %%
import pandas as pd 

df = pd.read_csv("csv/ai_job_dataset.csv")
df[(df['salary_usd']>300000) & (df['salary_currency']=="USD") ]
# Out:
#         job_id                  job_title  salary_usd salary_currency  \
# 67     AI00068  Machine Learning Engineer      316182             USD
# 137    AI00138  Machine Learning Engineer      324557             USD
# 185    AI00186     Deep Learning Engineer      300422             USD
# 215    AI00216       AI Software Engineer      301038             USD
# 317    AI00318             Data Scientist      388754             USD
# ...        ...                        ...         ...             ...
# 14705  AI14706              Data Engineer      328657             USD
# 14773  AI14774               Data Analyst      320379             USD
# 14872  AI14873              AI Specialist      302035             USD
# 14916  AI14917   Principal Data Scientist      307237             USD
# 14977  AI14978         Research Scientist      325968             USD
#
#       experience_level employment_type company_location company_size  \
# ...
