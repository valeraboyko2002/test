# %% [markdown]
# # Data Structures and Algorithms
# ## Ноутбук из Google Colab
#
# Этот файл был создан и загружен на GitHub из Google Colab

# %%
print("Hello GitHub!")
print("Этот ноутбук теперь на GitHub")
